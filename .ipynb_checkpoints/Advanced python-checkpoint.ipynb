# %% [markdown]
# # Part 1

# %%
import pandas as pd

# %%
df = pd.read_csv('python/faculty.csv')
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email
# 0  bellamys@mail.med.upenn.edu
# 1             warren@upenn.edu
# 2            bryanma@upenn.edu
# 3           jinboche@upenn.edu
# 4           sellenbe@upenn.edu

# %%
df.columns
# Out:
# Index([u'name', u' degree', u' title', u' email'], dtype='object')

# %%
df[' degree'].value_counts()
# Out:
#  Ph.D.                 15
#  PhD                    7
#  Sc.D.                  4
#  Ph.D                   4
#  JD MA MPH MS PhD       1
#  ScD                    1
# Ph.D.                   1
#  B.S.Ed. M.S. Ph.D.     1
#  PhD ScD                1
# 0                       1
#  MD MPH Ph.D            1
# Name:  degree, dtype: int64

# %%
df['clean_degree'] = df[' degree'].str.replace(".","").str.lower()

# %%
df['clean_degree']
# Out:
# 0                   scd
# 1                   phd
# 2                   phd
# 3                   phd
# 4                   phd
# 5                   phd
# 6                   phd
# 7                   phd
# 8                   phd
# 9                   phd
# 10                  phd
# 11                  phd
# 12                  phd
# 13           md mph phd
# 14          bsed ms phd
# 15                  phd
# 16                  phd
# 17                  phd
# 18     jd ma mph ms phd
# 19                  phd
# 20                  scd
# 21                  scd
# 22              phd scd
# 23                  phd
# 24                  phd
# 25                  phd
# 26                  scd
# 27                  phd
# 28                    0
# 29                  phd
# 30                  phd
# 31                  phd
# 32                  scd
# 33                  phd
# 34                  phd
# 35                  phd
# 36                  phd
# Name: clean_degree, dtype: object

# %%
degree_list = ['phd','scd','jd','ma','mph','ms','bs','ed','md']

for degree in degree_list:
    df[degree] = df['clean_degree'].str.contains(degree)

# %%
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email clean_degree    phd    scd     jd     ma  \
# 0  bellamys@mail.med.upenn.edu          scd  False   True  False  False
# 1             warren@upenn.edu          phd   True  False  False  False
# 2            bryanma@upenn.edu          phd   True  False  False  False
# 3           jinboche@upenn.edu          phd   True  False  False  False
# 4           sellenbe@upenn.edu          phd   True  False  False  False
#
#      mph     ms     bs     ed     md
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %%
for degree in degree_list:
    print str(degree) + ':' + str(sum(df[degree]))
# Out:
# phd:31
# scd:6
# jd:1
# ma:1
# mph:2
# ms:2
# bs:1
# ed:1
# md:1

# %%
df[' title'].value_counts()
# Out:
# Professor of Biostatistics              13
# Associate Professor of Biostatistics    12
# Assistant Professor of Biostatistics    11
# Assistant Professor is Biostatistics     1
# Name:  title, dtype: int64

# %%
prof_keywords = ['Associate','Assistant']
for key in prof_keywords:
    df[key] = df[' title'].str.contains(key)

df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email clean_degree    phd    scd     jd     ma  \
# 0  bellamys@mail.med.upenn.edu          scd  False   True  False  False
# 1             warren@upenn.edu          phd   True  False  False  False
# 2            bryanma@upenn.edu          phd   True  False  False  False
# 3           jinboche@upenn.edu          phd   True  False  False  False
# 4           sellenbe@upenn.edu          phd   True  False  False  False
#
#      mph     ms     bs     ed     md Associate Assistant
# 0  False  False  False  False  False      True     False
# 1  False  False  False  False  False     False     False
# 2  False  False  False  False  False     False      True
# 3  False  False  False  False  False      True     False
# 4  False  False  False  False  False     False     False

# %%
# for row in df:
#     if df['Associate'][row] == False and df['Assistant'][row] == False:
#         df['Professor'][row] = True

# %%
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email clean_degree    phd    scd     jd     ma  \
# 0  bellamys@mail.med.upenn.edu          scd  False   True  False  False
# 1             warren@upenn.edu          phd   True  False  False  False
# 2            bryanma@upenn.edu          phd   True  False  False  False
# 3           jinboche@upenn.edu          phd   True  False  False  False
# 4           sellenbe@upenn.edu          phd   True  False  False  False
#
#      mph     ms     bs     ed     md Associate Assistant
# 0  False  False  False  False  False      True     False
# 1  False  False  False  False  False     False     False
# 2  False  False  False  False  False     False      True
# 3  False  False  False  False  False      True     False
# 4  False  False  False  False  False     False     False

# %%
df.info
# Out:
# <bound method DataFrame.info of                          name               degree  \
# 0         Scarlett L. Bellamy                Sc.D.
# 1            Warren B. Bilker                Ph.D.
# 2             Matthew W Bryan                  PhD
# 3                  Jinbo Chen                Ph.D.
# 4           Susan S Ellenberg                Ph.D.
# 5          Jonas H. Ellenberg                Ph.D.
# 6                    Rui Feng                 Ph.D
# 7          Benjamin C. French                  PhD
# 8          Phyllis A. Gimotty                 Ph.D
# 9                Wensheng Guo                 Ph.D
# 10                Yenchih Hsu                Ph.D.
# 11          Rebecca A Hubbard                  PhD
# 12             Wei-Ting Hwang                Ph.D.
# 13          Marshall M. Joffe          MD MPH Ph.D
# 14          J. Richard Landis   B.S.Ed. M.S. Ph.D.
# 15                   Yimei Li                Ph.D.
# 16                 Mingyao Li                Ph.D.
# 17                 Hongzhe Li                 Ph.D
# 18         A. Russell Localio     JD MA MPH MS PhD
# 19              Nandita Mitra                Ph.D.
# 20        Knashawn H. Morales                Sc.D.
# 21       Kathleen Joy Propert                Sc.D.
# 22               Mary E. Putt              PhD ScD
# 23       Sarah Jane Ratcliffe                Ph.D.
# 24        Michelle Elana Ross                  PhD
# 25               Jason A. Roy                Ph.D.
# 26             Mary D. Sammel                Sc.D.
# 27            Pamela Ann Shaw                  PhD
# 28  Russell Takeshi Shinohara                    0
# 29              Haochang Shou                Ph.D.
# 30             Justine Shults                Ph.D.
# 31        Alisa Jane Stephens                Ph.D.
# 32         Andrea Beth Troxel                  ScD
# 33                   Rui Xiao                  PhD
# 34        Sharon Xiangwen Xie                Ph.D.
# 35                  Dawei Xie                  PhD
# 36           Wei (Peter) Yang                Ph.D.
#
#                                    title                        email  \
# 0   Associate Professor of Biostatistics  bellamys@mail.med.upenn.edu
# 1             Professor of Biostatistics             warren@upenn.edu
# 2   Assistant Professor of Biostatistics            bryanma@upenn.edu
# 3   Associate Professor of Biostatistics           jinboche@upenn.edu
# 4             Professor of Biostatistics           sellenbe@upenn.edu
# 5             Professor of Biostatistics  jellenbe@mail.med.upenn.edu
# 6   Assistant Professor of Biostatistics            ruifeng@upenn.edu
# 7   Associate Professor of Biostatistics  bcfrench@mail.med.upenn.edu
# 8             Professor of Biostatistics           pgimotty@upenn.edu
# 9             Professor of Biostatistics      wguo@mail.med.upenn.edu
# 10  Assistant Professor of Biostatistics      hsu9@mail.med.upenn.edu
# 11  Associate Professor of Biostatistics     rhubb@mail.med.upenn.edu
# 12  Associate Professor of Biostatistics    whwang@mail.med.upenn.edu
# 13            Professor of Biostatistics    mjoffe@mail.med.upenn.edu
# 14            Professor of Biostatistics  jrlandis@mail.med.upenn.edu
# 15  Assistant Professor of Biostatistics          liy3@email.chop.edu
# 16  Associate Professor of Biostatistics   mingyao@mail.med.upenn.edu
# 17            Professor of Biostatistics            hongzhe@upenn.edu
# 18  Associate Professor of Biostatistics           rlocalio@upenn.edu
# 19  Associate Professor of Biostatistics  nanditam@mail.med.upenn.edu
# 20  Associate Professor of Biostatistics  knashawn@mail.med.upenn.edu
# 21            Professor of Biostatistics   propert@mail.med.upenn.edu
# 22            Professor of Biostatistics     mputt@mail.med.upenn.edu
# 23  Associate Professor of Biostatistics           sratclif@upenn.edu
# 24  Assistant Professor is Biostatistics           michross@upenn.edu
# 25  Associate Professor of Biostatistics     jaroy@mail.med.upenn.edu
# 26            Professor of Biostatistics   msammel@cceb.med.upenn.edu
# 27  Assistant Professor of Biostatistics              shawp@upenn.edu
# 28  Assistant Professor of Biostatistics      rshi@mail.med.upenn.edu
# 29  Assistant Professor of Biostatistics     hshou@mail.med.upenn.edu
# 30            Professor of Biostatistics   jshults@mail.med.upenn.edu
# 31  Assistant Professor of Biostatistics  alisaste@mail.med.upenn.edu
# 32            Professor of Biostatistics   atroxel@mail.med.upenn.edu
# 33  Assistant Professor of Biostatistics     rxiao@mail.med.upenn.edu
# 34  Associate Professor of Biostatistics      sxie@mail.med.upenn.edu
# 35  Assistant Professor of Biostatistics               dxie@upenn.edu
# 36  Assistant Professor of Biostatistics   weiyang@mail.med.upenn.edu
#
#          clean_degree    phd    scd     jd     ma    mph     ms     bs     ed  \
# 0                 scd  False   True  False  False  False  False  False  False
# 1                 phd   True  False  False  False  False  False  False  False
# 2                 phd   True  False  False  False  False  False  False  False
# 3                 phd   True  False  False  False  False  False  False  False
# 4                 phd   True  False  False  False  False  False  False  False
# 5                 phd   True  False  False  False  False  False  False  False
# 6                 phd   True  False  False  False  False  False  False  False
# 7                 phd   True  False  False  False  False  False  False  False
# 8                 phd   True  False  False  False  False  False  False  False
# 9                 phd   True  False  False  False  False  False  False  False
# 10                phd   True  False  False  False  False  False  False  False
# 11                phd   True  False  False  False  False  False  False  False
# 12                phd   True  False  False  False  False  False  False  False
# 13         md mph phd   True  False  False  False   True  False  False  False
# 14        bsed ms phd   True  False  False  False  False   True   True   True
# 15                phd   True  False  False  False  False  False  False  False
# 16                phd   True  False  False  False  False  False  False  False
# 17                phd   True  False  False  False  False  False  False  False
# 18   jd ma mph ms phd   True  False   True   True   True   True  False  False
# 19                phd   True  False  False  False  False  False  False  False
# 20                scd  False   True  False  False  False  False  False  False
# 21                scd  False   True  False  False  False  False  False  False
# 22            phd scd   True   True  False  False  False  False  False  False
# 23                phd   True  False  False  False  False  False  False  False
# 24                phd   True  False  False  False  False  False  False  False
# 25                phd   True  False  False  False  False  False  False  False
# 26                scd  False   True  False  False  False  False  False  False
# 27                phd   True  False  False  False  False  False  False  False
# 28                  0  False  False  False  False  False  False  False  False
# 29                phd   True  False  False  False  False  False  False  False
# 30                phd   True  False  False  False  False  False  False  False
# 31                phd   True  False  False  False  False  False  False  False
# 32                scd  False   True  False  False  False  False  False  False
# 33                phd   True  False  False  False  False  False  False  False
# 34                phd   True  False  False  False  False  False  False  False
# 35                phd   True  False  False  False  False  False  False  False
# 36                phd   True  False  False  False  False  False  False  False
#
#        md Associate Assistant
# 0   False      True     False
# 1   False     False     False
# 2   False     False      True
# 3   False      True     False
# 4   False     False     False
# 5   False     False     False
# 6   False     False      True
# 7   False      True     False
# 8   False     False     False
# 9   False     False     False
# 10  False     False      True
# 11  False      True     False
# 12  False      True     False
# 13   True     False     False
# 14  False     False     False
# 15  False     False      True
# 16  False      True     False
# 17  False     False     False
# 18  False      True     False
# 19  False      True     False
# 20  False      True     False
# 21  False     False     False
# 22  False     False     False
# 23  False      True     False
# 24  False     False      True
# 25  False      True     False
# 26  False     False     False
# 27  False     False      True
# 28  False     False      True
# 29  False     False      True
# 30  False     False     False
# 31  False     False      True
# 32  False     False     False
# 33  False     False      True
# 34  False      True     False
# 35  False     False      True
# 36  False     False      True  >

# %%
total_nonprof = 0
for p in prof_keywords:
    total_nonprof += sum(df[p])
    print str(p) + ':' + str(sum(df[p]))
print "Professor" + ':' + str(37 - total_nonprof)
# Out:
# Associate:12
# Assistant:12
# Professor:13

# %%
email_list = list(df[' email'])
print email_list
# Out:
# ['bellamys@mail.med.upenn.edu', 'warren@upenn.edu', 'bryanma@upenn.edu', 'jinboche@upenn.edu', 'sellenbe@upenn.edu', 'jellenbe@mail.med.upenn.edu', 'ruifeng@upenn.edu', 'bcfrench@mail.med.upenn.edu', 'pgimotty@upenn.edu', 'wguo@mail.med.upenn.edu', 'hsu9@mail.med.upenn.edu', 'rhubb@mail.med.upenn.edu', 'whwang@mail.med.upenn.edu', 'mjoffe@mail.med.upenn.edu', 'jrlandis@mail.med.upenn.edu', 'liy3@email.chop.edu', 'mingyao@mail.med.upenn.edu', 'hongzhe@upenn.edu', 'rlocalio@upenn.edu', 'nanditam@mail.med.upenn.edu', 'knashawn@mail.med.upenn.edu', 'propert@mail.med.upenn.edu', 'mputt@mail.med.upenn.edu', 'sratclif@upenn.edu', 'michross@upenn.edu', 'jaroy@mail.med.upenn.edu', 'msammel@cceb.med.upenn.edu', 'shawp@upenn.edu', 'rshi@mail.med.upenn.edu', 'hshou@mail.med.upenn.edu', 'jshults@mail.med.upenn.edu', 'alisaste@mail.med.upenn.edu', 'atroxel@mail.med.upenn.edu', 'rxiao@mail.med.upenn.edu', 'sxie@mail.med.upenn.edu', 'dxie@upenn.edu', 'weiyang@mail.med.upenn.edu']

# %%
email_split = df[' email'].apply(lambda email: pd.Series(email.split('@')))
email_set = set(email_split[1])
print email_set
# Out:
# set(['email.chop.edu', 'upenn.edu', 'cceb.med.upenn.edu', 'mail.med.upenn.edu'])

# %% [markdown]
# # Part 2

# %%
df[' email'].to_csv('python/emails.csv')

# %%
# split = lambda x: x.split('')
# name_split = [split for x in df['name']]

# %% [markdown]
# # Part 3

# %%
df['first_name'] = df['name'].str.split(' ').str.get(0)
df['first_name'].head()
# Out:
# 0    Scarlett
# 1      Warren
# 2     Matthew
# 3       Jinbo
# 4       Susan
# Name: first_name, dtype: object

# %%
df['last_name'] = df['name'].str.rsplit(' ', n=1).str.get(1)
df['last_name'].head()
# Out:
# 0      Bellamy
# 1       Bilker
# 2        Bryan
# 3         Chen
# 4    Ellenberg
# Name: last_name, dtype: object

# %%
df[['first_name','last_name']].head()
# Out:
#   first_name  last_name
# 0   Scarlett    Bellamy
# 1     Warren     Bilker
# 2    Matthew      Bryan
# 3      Jinbo       Chen
# 4      Susan  Ellenberg

# %%
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email clean_degree    phd    scd     jd     ma  \
# 0  bellamys@mail.med.upenn.edu          scd  False   True  False  False
# 1             warren@upenn.edu          phd   True  False  False  False
# 2            bryanma@upenn.edu          phd   True  False  False  False
# 3           jinboche@upenn.edu          phd   True  False  False  False
# 4           sellenbe@upenn.edu          phd   True  False  False  False
#
#      mph     ms     bs     ed     md Associate Assistant first_name  last_name
# 0  False  False  False  False  False      True     False   Scarlett    Bellamy
# 1  False  False  False  False  False     False     False     Warren     Bilker
# 2  False  False  False  False  False     False      True    Matthew      Bryan
# 3  False  False  False  False  False      True     False      Jinbo       Chen
# 4  False  False  False  False  False     False     False      Susan  Ellenberg

# %%
df.loc[1]['name']
# Out:
# 'Warren B. Bilker'

# %%
Professorship = []

for index, row in df.iterrows():
    if row['Associate'] == True:
        Professorship.append('Associate')
#         row['Professorship'] = 'Associate'
    elif row['Assistant'] == True:
        Professorship.append('Assistant')
#         row['Professorship'] = 'Assistant'
    else:
        Professorship.append('Professor')
#         row['Professorship'] = 'Professor'

df['Professorship'] = Professorship
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email clean_degree    phd    scd     jd     ma  \
# 0  bellamys@mail.med.upenn.edu          scd  False   True  False  False
# 1             warren@upenn.edu          phd   True  False  False  False
# 2            bryanma@upenn.edu          phd   True  False  False  False
# 3           jinboche@upenn.edu          phd   True  False  False  False
# 4           sellenbe@upenn.edu          phd   True  False  False  False
#
#      mph     ms     bs     ed     md Associate Assistant first_name  \
# 0  False  False  False  False  False      True     False   Scarlett
# 1  False  False  False  False  False     False     False     Warren
# 2  False  False  False  False  False     False      True    Matthew
# 3  False  False  False  False  False      True     False      Jinbo
# 4  False  False  False  False  False     False     False      Susan
#
#    last_name Professorship
# 0    Bellamy     Associate
# 1     Bilker     Professor
# 2      Bryan     Assistant
# 3       Chen     Associate
# 4  Ellenberg     Professor

# %%
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email clean_degree    phd    scd     jd     ma  \
# 0  bellamys@mail.med.upenn.edu          scd  False   True  False  False
# 1             warren@upenn.edu          phd   True  False  False  False
# 2            bryanma@upenn.edu          phd   True  False  False  False
# 3           jinboche@upenn.edu          phd   True  False  False  False
# 4           sellenbe@upenn.edu          phd   True  False  False  False
#
#      mph     ms     bs     ed     md Associate Assistant first_name  last_name
# 0  False  False  False  False  False      True     False   Scarlett    Bellamy
# 1  False  False  False  False  False     False     False     Warren     Bilker
# 2  False  False  False  False  False     False      True    Matthew      Bryan
# 3  False  False  False  False  False      True     False      Jinbo       Chen
# 4  False  False  False  False  False     False     False      Susan  Ellenberg

# %%
info = []
for index, row in df.iterrows():
        info.append([row['clean_degree'],row['Professorship'],row[' email']])

df['info'] = info
df.head()
# Out:
#                   name  degree                                 title  \
# 0  Scarlett L. Bellamy   Sc.D.  Associate Professor of Biostatistics
# 1     Warren B. Bilker   Ph.D.            Professor of Biostatistics
# 2      Matthew W Bryan     PhD  Assistant Professor of Biostatistics
# 3           Jinbo Chen   Ph.D.  Associate Professor of Biostatistics
# 4    Susan S Ellenberg   Ph.D.            Professor of Biostatistics
#
#                          email clean_degree    phd    scd     jd     ma  \
# 0  bellamys@mail.med.upenn.edu          scd  False   True  False  False
# 1             warren@upenn.edu          phd   True  False  False  False
# 2            bryanma@upenn.edu          phd   True  False  False  False
# 3           jinboche@upenn.edu          phd   True  False  False  False
# 4           sellenbe@upenn.edu          phd   True  False  False  False
#
#      mph     ms     bs     ed     md Associate Assistant first_name  \
# 0  False  False  False  False  False      True     False   Scarlett
# 1  False  False  False  False  False     False     False     Warren
# 2  False  False  False  False  False     False      True    Matthew
# 3  False  False  False  False  False      True     False      Jinbo
# 4  False  False  False  False  False     False     False      Susan
#
#    last_name Professorship                                            info
# 0    Bellamy     Associate  [ scd, Associate, bellamys@mail.med.upenn.edu]
# 1     Bilker     Professor              [phd, Professor, warren@upenn.edu]
# 2      Bryan     Assistant            [ phd, Assistant, bryanma@upenn.edu]
# 3       Chen     Associate           [ phd, Associate, jinboche@upenn.edu]
# 4  Ellenberg     Professor           [ phd, Professor, sellenbe@upenn.edu]

# %%
df_dict = df[['last_name','info']]
df_dict.head()
# Out:
#    last_name                                            info
# 0    Bellamy  [ scd, Associate, bellamys@mail.med.upenn.edu]
# 1     Bilker              [phd, Professor, warren@upenn.edu]
# 2      Bryan            [ phd, Assistant, bryanma@upenn.edu]
# 3       Chen           [ phd, Associate, jinboche@upenn.edu]
# 4  Ellenberg           [ phd, Professor, sellenbe@upenn.edu]

# %%
new_dict = df_dict.set_index('last_name')['info'].T.to_dict()
print new_dict
# Out:
# {'Putt': [' phd scd', 'Professor', 'mputt@mail.med.upenn.edu'], 'Feng': [' phd', 'Assistant', 'ruifeng@upenn.edu'], 'Bilker': ['phd', 'Professor', 'warren@upenn.edu'], 'Shaw': [' phd', 'Assistant', 'shawp@upenn.edu'], 'Landis': [' bsed ms phd', 'Professor', 'jrlandis@mail.med.upenn.edu'], 'Propert': [' scd', 'Professor', 'propert@mail.med.upenn.edu'], 'Gimotty': [' phd', 'Professor', 'pgimotty@upenn.edu'], 'Joffe': [' md mph phd', 'Professor', 'mjoffe@mail.med.upenn.edu'], 'Ellenberg': [' phd', 'Professor', 'jellenbe@mail.med.upenn.edu'], 'Hubbard': [' phd', 'Associate', 'rhubb@mail.med.upenn.edu'], 'Morales': [' scd', 'Associate', 'knashawn@mail.med.upenn.edu'], 'Mitra': [' phd', 'Associate', 'nanditam@mail.med.upenn.edu'], 'Ross': [' phd', 'Assistant', 'michross@upenn.edu'], 'Troxel': [' scd', 'Professor', 'atroxel@mail.med.upenn.edu'], 'French': [' phd', 'Associate', 'bcfrench@mail.med.upenn.edu'], 'Ratcliffe': [' phd', 'Associate', 'sratclif@upenn.edu'], 'Hsu': [' phd', 'Assistant', 'hsu9@mail.med.upenn.edu'], 'Shults': [' phd', 'Professor', 'jshults@mail.med.upenn.edu'], 'Xie': [' phd', 'Assistant', 'dxie@upenn.edu'], 'Shinohara': ['0', 'Assistant', 'rshi@mail.med.upenn.edu'], 'Bryan': [' phd', 'Assistant', 'bryanma@upenn.edu'], 'Guo': [' phd', 'Professor', 'wguo@mail.med.upenn.edu'], 'Localio': [' jd ma mph ms phd', 'Associate', 'rlocalio@upenn.edu'], 'Yang': [' phd', 'Assistant', 'weiyang@mail.med.upenn.edu'], 'Sammel': [' scd', 'Professor', 'msammel@cceb.med.upenn.edu'], 'Li': [' phd', 'Professor', 'hongzhe@upenn.edu'], 'Hwang': [' phd', 'Associate', 'whwang@mail.med.upenn.edu'], 'Bellamy': [' scd', 'Associate', 'bellamys@mail.med.upenn.edu'], 'Shou': [' phd', 'Assistant', 'hshou@mail.med.upenn.edu'], 'Stephens': [' phd', 'Assistant', 'alisaste@mail.med.upenn.edu'], 'Xiao': [' phd', 'Assistant', 'rxiao@mail.med.upenn.edu'], 'Roy': [' phd', 'Associate', 'jaroy@mail.med.upenn.edu'], 'Chen': [' phd', 'Associate', 'jinboche@upenn.edu']}

# %%
new_dict['Bellamy']
# Out:
# {' email': 'bellamys@mail.med.upenn.edu',
#  'Professorship': 'Associate',
#  'clean_degree': ' scd'}
